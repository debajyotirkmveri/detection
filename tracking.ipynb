# %% [markdown]
# ## Multi-Object Tracking with Ultralytics YOLO

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8n.pt')  # Load an official Detect model


# Perform tracking with the model
#results = model.track(source="2.mp4", save=True)  # Tracking with default tracker (The default tracker is BoT-SORT.)
#results = model.track(source="c.jpg", save=True) 
results = model.track(source="https://youtu.be/LNwODJXcvt4", show=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# requirements: Ultralytics requirements ['pafy', 'youtube_dl==2020.12.2'] not found, attempting AutoUpdate...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.2 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 5.0s, installed 2 packages: ['pafy', 'youtube_dl==2020.12.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# 1/1: https://youtu.be/LNwODJXcvt4... Success ✅ (10842 frames of shape 1920x1080 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
# ...

# %%
from ultralytics import YOLO

# Configure the tracking parameters and run the tracker
model = YOLO('yolov8n.pt')

results = model.track(source="p.mp4",conf=0.7, iou=0.5, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 2 persons, 685.2ms
# video 1/1 (2/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 1 person, 490.0ms
# video 1/1 (3/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 2 persons, 85.7ms
# ...

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8n-seg.pt')  # Load an official Segment model

# Perform tracking with the model
#results = model.track(source="HeartofStoneNetflix.mp4", save=True) # Tracking with default tracker
results = model.track(source="p.mp4", save=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# ...
# 100%|██████████████████████████████████████| 6.73M/6.73M [00:00<00:00, 22.7MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 2 persons, 937.6ms
# video 1/1 (2/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 2 persons, 270.3ms
# ...

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov8n-pose.pt')  # Load an official Pose model

# Perform tracking with the model
results = model.track(source="p.mp4", save=True) # Tracking with default tracker
#results = model.track(source="https://youtu.be/LNwODJXcvt4", show=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# ...
# 100%|██████████████████████████████████████| 6.51M/6.51M [00:00<00:00, 23.8MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 1 person, 57.3ms
# video 1/1 (2/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 1 person, 42.3ms
# video 1/1 (3/394) /home/sysadm/Downloads/Multi-Object-Tracking-with-Ultralytics-YOLO/p.mp4: 384x640 1 person, 35.6ms
# ...

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('best.pt')  # Load a custom trained model

# Perform tracking with the model
results = model.track(source="p.mp4", save=True)  # Tracking with default tracker
#results = model.track(source="tejas.mp4", save=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 from ultralytics import YOLO
#       3 # Load an official or custom model
# ----> 4 model = YOLO('best.pt')  # Load a custom trained model
#       6 # Perform tracking with the model
#       7 results = model.track(source="p.mp4", save=True)  # Tracking with default tracker
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:134, in Model.__init__(self, model, task, verbose)
#     132     self._new(model, task=task, verbose=verbose)
#     133 else:
# --> 134     self._load(model, task=task)
#     136 self.model_name = model
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:215, in Model._load(self, weights, task)
#     213 suffix = Path(weights).suffix
#     214 if suffix == ".pt":
# --> 215     self.model, self.ckpt = attempt_load_one_weight(weights)
# ...

# %% [markdown]
# Configuration files are here:
#
# ### https://github.com/ultralytics/ultralytics/tree/main/ultralytics/cfg/trackers
